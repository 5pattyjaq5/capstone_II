# %% [markdown]
# # Water Potability
# ###### Patricia Jaquez
# ###### DATE:  June 22, 2013
# ###### dataset url : 'https://www.kaggle.com/datasets/adityakadiwal/water-potability'

# %% [markdown]
# # Hypothesis
#
# As time progresses we learn what is and what isnt healthy for us. Same goes with the quality of our drinking water, not all water is great for consumption and learning the contents of what water has plays a huge factor, is it in reality is good for consumption, or as some would say potable or not.
#
# I started with building a notebook in which I cleaned the data, so I could see its contents. Building a scatter plot and seeing how certain levels of ph value with other factors make water okay for consumption.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# After finishing up my notebook, i built my base aka my pipeline to be able to build my streamlit app. Connected to my tomongo, build my .env file as well
# as my gitignore file to shield my database from unwanted access. Once, that was done I was able to build my front page and I was able to connect to my streamlit app, built my
# pages folder, where I also added my information page where it describes the contents of whata affects water.
#
# Overall, a great quality drinking water is between 6.5 to 8.5 with up to 4 milligrams of chloramines, with levels of 200 or less of tds,hardness levels of 0 - 17 mg/L & ppm,
# conductivity of less than 400 μS/cm. SO when it comes down to choosing the right water to drink, we must take these factor into account.
